# %%
s='8'*68
print(s)
s = s.replace ('888','Ф',1)
print(s)
# Out:
# 88888888888888888888888888888888888888888888888888888888888888888888
# Ф88888888888888888888888888888888888888888888888888888888888888888

# %%
s='8'*68
print(s)
s = s.replace ('888','Ф')
print(s)
# Out:
# 88888888888888888888888888888888888888888888888888888888888888888888
# ФФФФФФФФФФФФФФФФФФФФФФ88

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s='8'*68
while ('222' in s) or ('888' in s):
    if ('222' in s): 
        s = s.replace ('222','8',1)
    else:
        s=s.replace ('888','2',1)
print(s)
# Out:
# 28

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s='9'*127
while ('333' in s) or ('999' in s):
    if ('333' in s): 
        s = s.replace ('333','9',1)
    else:
        s = s.replace ('999','3',1)
print(s)
# Out:
# 339

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s='1'+'8'*80
while ('18' in s) or ('288' in s) or ('3888' in s):
    if ('18' in s): 
        s = s.replace ('18','2',1)
    elif ('288' in s): 
        s = s.replace ('288','3',1)
    else:
        s = s.replace ('3888','1',1)
print(s)
# Out:
# 28

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s='8'*125
while ('333' in s) or ('888' in s) :
    if ('333' in s): 
        s = s.replace ('333','8',1)
    else:
        s = s.replace ('888','3',1)
print(s)
# Out:
# 388

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = '5' * 54 + '7'
while ('722' in s) or ('557' in s):
    if '722' in s:
        s = s.replace('722', '57', 1)
    else:
        s = s.replace('557', '72', 1)
print(s)
# Out:
# 572

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
77888=7+7+8+8+8

# %%
2*7+3*8

# %%
s = '>' + '1' * 26 + '2' * 10 + '3' * 14
while ('>1' in s) or ('>2' in s) or ('>3' in s):
    if '>1' in s:
        s = s.replace('>1', '22>', 1)
    if '>2' in s:
        s = s.replace('>2', '2>', 1)
    if '>3' in s:
        s = s.replace('>3', '1>', 1)

print('сумма цифр:', s.count('1')*1 + s.count('2') * 2+ s.count('3') * 3)
# Out:
# сумма цифр: 138

# %%
122222333333
1+2*5+3*6

# %%
m = 10*5
i = 0
for n in range(201,300):
  s = n'1'
  while '111' in s or '222' in s:
    s = s.replace('111','22',1)
    s = s.replace('222','1',1)
    if m > s.count('2'):
      m = s.count('2')
      i = n
print(i)
# Out:
#   File "<ipython-input-13-ff1c036d22da>", line 4
#     s = n'1'
#          ^
# SyntaxError: invalid syntax

# %%
for i in range(201, 240):
    s = '1' * i
    while ('1111' in s) :
        s = s.replace('1111', '22', 1)
        s = s.replace('222', '1', 1)

# %% [markdown]
# 72 ![image.png](attachment:image.png)

# %%
minn = 1000
itog = 0
for i in range(201, 1000):
    s = '1' * i
    while ('1111' in s) :
        s = s.replace('1111', '22', 1)
        s = s.replace('222', '1', 1)
    if minn > s.count('1'):
        minn = s.count('1')
        itog = i
print(itog)
# Out:
# 204

# %%
minn = 1000
itog = 0
for i in range(101, 1000):
    s = '1' * i
    while ('111' in s):
        s = s.replace('111', '22', 1)
        s = s.replace('222', '11', 1)
    if minn > s.count('1'):
        minn = s.count('1')
        itog = i
print(itog)
# Out:
# 104

# %%
for i in range(201,300):
    strng = '1' * i
    while ('111' in strng):
        strng = strng.replace('111', '22', 1)
        strng = strng.replace('222', '11', 1)
    print(i,strng)
# Out:
# 201 112
# 202 1121
# 203 11211
# 204 221
# 205 2211
# 206 112
# 207 1121
# 208 11211
# 209 221
# 210 2211
# 211 112
# 212 1121
# 213 11211
# 214 221
# 215 2211
# 216 112
# 217 1121
# 218 11211
# 219 221
# 220 2211
# 221 112
# 222 1121
# 223 11211
# 224 221
# 225 2211
# 226 112
# 227 1121
# 228 11211
# 229 221
# 230 2211
# 231 112
# 232 1121
# 233 11211
# 234 221
# 235 2211
# 236 112
# 237 1121
# 238 11211
# 239 221
# 240 2211
# 241 112
# 242 1121
# 243 11211
# 244 221
# 245 2211
# 246 112
# 247 1121
# 248 11211
# 249 221
# 250 2211
# 251 112
# 252 1121
# 253 11211
# 254 221
# 255 2211
# 256 112
# 257 1121
# 258 11211
# 259 221
# 260 2211
# 261 112
# 262 1121
# 263 11211
# 264 221
# 265 2211
# 266 112
# 267 1121
# 268 11211
# 269 221
# 270 2211
# 271 112
# 272 1121
# 273 11211
# 274 221
# 275 2211
# 276 112
# 277 1121
# 278 11211
# 279 221
# 280 2211
# 281 112
# 282 1121
# 283 11211
# 284 221
# 285 2211
# 286 112
# 287 1121
# 288 11211
# 289 221
# 290 2211
# 291 112
# 292 1121
# ...

# %%
max = 0
end = 0

for i in range(101, 1000):
    s = '1' * i 
    while('111' in s):
        s = s.replace ('111', '22', 1)
        s = s.replace ('222', '11', 1)

    if max < s.count('1'):
        max = s.count('1')
        end = i
print(end)
# Out:
# 103

# %% [markdown]
# 76.
# ![image.png](attachment:image.png)

# %%
s = '8' * 84
while '1111' in s or '8888' in s:
    if '1111' in s:
        s = s.replace('1111', '8', 1)
    else:
        s = s.replace('8888', '11', 1)
print(s)
# Out:
# 11888

# %% [markdown]
# 77.
# ![image.png](attachment:image.png)

# %%
for i1 in range(1,62):
    for i2 in range(1,62):
        for i3 in range(1,62):
            a = "0" + i1 * "1" + i2 * "2" + i3 * "3" + "0"
            while "00" not in a:
                a = a.replace('01', '210', 1)
                a = a.replace("02", "3101", 1)
                a = a.replace("03", "2012", 1)
            if a.count("1") == 61 and a.count("2") == 50 and a.count("3") == 18:
                print(i1 + i2 + i3 + 2)
# Out:
# 38

# %% [markdown]
# 76.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = ">" + 39*"0" + 0*'1'+ 39*'2'
while ">1" in a or ">2" in a or ">0" in a:
    if ">1" in a:
        a = a.replace(">1","22>", 1)
    if ">2" in a:
        a = a.replace(">2","2>", 1)
    if ">0" in a:
        a = a.replace(">0", "1>", 1)
print(a)
# Out:
# 111111111111111111111111111111111111111222222222222222222222222222222222222222>

# %%
a = a.replace(">", "")
a = list(map(int, a))
print(sum(a))
# Out:
# 117

# %%
import math
def pr(n):
    for i in range(2, int(math.sqrt(n))+1):
        if n % i == 0:
            return False
    else:
        return True

for i in range (1, 100):
    a = ">" + 39*"0" + i*'1'+ 39*'2'
    while ">1" in a or ">2" in a or ">0" in a:
        if ">1" in a:
            a = a.replace(">1","22>", 1)
        if ">2" in a:
            a = a.replace(">2","2>", 1)
        if ">0" in a:
            a = a.replace(">0", "1>", 1)
    a = a.replace(">", "")
    a = list(map(int, a))
    if pr(sum(a)):
        print(i)
        break
# Out:
# 5

# %%
s = input()
s = s.split()
print(' '.join())
# Out:
#    vfvf   tkf rfir
# ['vfvf', 'tkf', 'rfir']

# %%
1/3
# Out:
# 0.3333333333333333

# %%
1/1
# Out:
# 1.0

# %%
s = input()
for i in range(len(s)-1):
    if s[i] != ' ' and s[i+1] != ' ':
        print(s[i],end = '')

# %%
for n in range(1,100):
    s = '1'*10 + '2'*n
    while('21' in s):
        s = s.replace('21', '5', 1)
    if s.count('5')*5  + s.count('2')*2 + s.count('1')*1 == 34:
        print(n)
# Out:
# 12

# %%
s = '1'*10 + '2'*6
while('21' in s):
    s = s.replace('21', '5', 1)
print(s)
# Out:
# 1111111111222222

# %%
s = '1' * 10 + '2' * 4

while('11' in s):
    if ('112' in s):
        s = s.replace('112', '6', 1)
    else:
        s = s.replace('11', '3', 1)
print(s)
# Out:
# 33336222

# %%
s = '112' * 4 + '1' * 2
s
# Out:
# '11211211211211'

# %%
s = '112' * 4 + '1' * 2
while('11' in s):
    if ('112' in s):
        s = s.replace('112', '6', 1)
    else:
        s = s.replace('11', '3', 1)
print(s)
# Out:
# 66663
